# %% [markdown]
# ## Reshaping Data for Visualization

# %%
# To list files in a directory
import os 

# For data manipulation
import pandas as pd
import numpy as np

from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="fwiVyb"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("fwiVyb").appendChild(div);
#                     };
#                     var e = document.getElementById("fwiVyb");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
# List all files in the ME204/data/waitrose folder
all_files = [os.path.join('../data/waitrose', file) for file in os.listdir('../data/waitrose') 
             if file.endswith('.csv')]

# Read every single file and concatenate them into a single DataFrame with pandas concat
df = pd.concat((pd.read_csv(file) for file in all_files))

# %%
df
# Out:
#       data-product-id                                  data-product-name  \
# 0              525635           Organix Raspberry & Apple Soft Oaty Bars
# 1              557746                      Organix Carrot Cake Oaty Bars
# 2               32062                           Aptamil 2 Follow On Milk
# 3              767801                               Essential Baby Wipes
# 4              514054                           Organix Apple Rice Cakes
# ...               ...                                                ...
# 1589            18427                Duchy Organic British Lamb Half Leg
# 1590            11606                         Cooks' Ingredients Wok Oil
# 1591             6903  No. 1 Badoz Vacherin Du Haut-Doubs AOP French ...
# 1592             6125                  Cooks' Ingredients White Marzipan
# 1593           707668              Duchy Organic Pinot Grigio Bag in Box
#
#      data-product-type  data-product-on-offer  data-product-index  \
# 0                    G                  False                 1.0
# 1                    G                  False                 2.0
# 2                    G                  False               394.0
# 3                    G                  False                 4.0
# 4                    G                  False                 5.0
# ...                ...                    ...                 ...
# 1589                 G                  False              1590.0
# 1590                 G                  False              1591.0
# 1591                 G                  False              1592.0
# 1592                 G                  False              1593.0
# 1593                 W                  False              1594.0
#
#                                               image-url  \
# 0     https://ecom-su-static-prod.wtrecom.com/images...
# 1     https://ecom-su-static-prod.wtrecom.com/images...
# 2     https://ecom-su-static-prod.wtrecom.com/images...
# 3     https://ecom-su-static-prod.wtrecom.com/images...
# 4     https://ecom-su-static-prod.wtrecom.com/images...
# ...                                                 ...
# 1589  https://ecom-su-static-prod.wtrecom.com/images...
# 1590  https://ecom-su-static-prod.wtrecom.com/images...
# 1591  https://ecom-su-static-prod.wtrecom.com/images...
# 1592  https://ecom-su-static-prod.wtrecom.com/images...
# 1593  https://ecom-su-static-prod.wtrecom.com/images...
#
#                                            product-page  \
# 0     https://www.waitrose.com/ecom/products/organix...
# 1     https://www.waitrose.com/ecom/products/organix...
# 2     https://www.waitrose.com/ecom/products/aptamil...
# 3     https://www.waitrose.com/ecom/products/essenti...
# 4     https://www.waitrose.com/ecom/products/organix...
# ...                                                 ...
# 1589  https://www.waitrose.com/ecom/products/duchy-o...
# 1590  https://www.waitrose.com/ecom/products/cooks-i...
# 1591  https://www.waitrose.com/ecom/products/no-1-ba...
# 1592  https://www.waitrose.com/ecom/products/cooks-i...
# 1593  https://www.waitrose.com/ecom/products/duchy-o...
#
#                                            product-name  \
# 0              Organix Raspberry & Apple Soft Oaty Bars
# 1                         Organix Carrot Cake Oaty Bars
# 2                              Aptamil 2 Follow On Milk
# 3                                  Essential Baby Wipes
# 4                              Organix Apple Rice Cakes
# ...                                                 ...
# 1589                Duchy Organic British Lamb Half Leg
# 1590                         Cooks' Ingredients Wok Oil
# 1591  No. 1 Badoz Vacherin Du Haut-Doubs AOP French ...
# 1592                  Cooks' Ingredients White Marzipan
# 1593              Duchy Organic Pinot Grigio Bag in Box
#
#                product-size        item-price price-per-unit  \
# 0                     6x23g             £3.15     £2.29/100g
# 1                     6x23g             £3.15     £2.29/100g
# 2                      800g            £13.50      £16.88/kg
# 3                       80s               95p      1.2p each
# 4                       40g             £1.60        £4/100g
# ...                     ...               ...            ...
# 1589  Typical weight 0.94kg  £24.31 each est.      £26.00/kg
# 1590                  250ml             £2.40      96p/100ml
# 1591                   350g            £10.00      £28.58/kg
# 1592                   500g             £2.50          £5/kg
# 1593                  2.25L            £21.49     £7.17/75cl
#
#      offer-description              category
# 0                  NaN  Baby, Child & Parent
# 1                  NaN  Baby, Child & Parent
# 2                  NaN  Baby, Child & Parent
# 3                  NaN  Baby, Child & Parent
# 4                  NaN  Baby, Child & Parent
# ...                ...                   ...
# 1589               NaN       Waitrose Brands
# 1590               NaN       Waitrose Brands
# 1591               NaN       Waitrose Brands
# 1592               NaN       Waitrose Brands
# 1593               NaN       Waitrose Brands
#
# [25418 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25418 entries, 0 to 1593
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   data-product-id        25418 non-null  int64
#  1   data-product-name      25418 non-null  object
#  2   data-product-type      25418 non-null  object
#  3   data-product-on-offer  25418 non-null  bool
#  4   data-product-index     25408 non-null  float64
#  5   image-url              25418 non-null  object
#  6   product-page           25418 non-null  object
#  7   product-name           25407 non-null  object
#  8   product-size           25363 non-null  object
#  9   item-price             25407 non-null  object
#  10  price-per-unit         24976 non-null  object
#  11  offer-description      7201 non-null   object
#  12  category               25418 non-null  object
# dtypes: bool(1), float64(1), int64(1), object(10)
# memory usage: 2.5+ MB

# %%
# Drop duplicates
df = df.drop_duplicates()

df = df.drop(columns=['data-product-name', 
                      'data-product-type', 
                      'data-product-index'])
df = (
    df.rename(columns={
        'data-product-id': 'id',
        'data-product-on-offer': 'offer',
        'product-page': 'page',
        'product-name': 'name',
        'product-size': 'size',
    })
)

# The id does not need 64 bits. 32 bits is enough.
# See https://numpy.org/doc/stable/reference/arrays.scalars.html#numpy.intc for ranges.
df['id'] = df['id'].astype('int32')

# %%
def clean_item_price(item_price: str):    
    """
    Cleans the item price string by performing necessary transformations.

    Parameters:
    item_price (str): The item price as a string.

    Returns:
    str: The cleaned item price.
    """
    if ' each est.' in item_price:
        item_price = item_price.replace(' each est.','')

    if type(item_price) != str:
        pass
    
    elif '£' in item_price:
        item_price = item_price.replace('£', '')
    elif 'p' in item_price:
        item_price = item_price.replace('p', '')
        item_price = '0.' + item_price
    if'-' in item_price:
        item_price=item_price.split('-')[0]
        
    return float(item_price)

# %%
df['item-price-fixed']=df['item-price'].astype(str).apply(clean_item_price)
df[['item-price-fixed','item-price']]
# Out:
#       item-price-fixed        item-price
# 0                 3.15             £3.15
# 1                 3.15             £3.15
# 2                13.50            £13.50
# 3                 0.95               95p
# 4                 1.60             £1.60
# ...                ...               ...
# 1589             24.31  £24.31 each est.
# 1590              2.40             £2.40
# 1591             10.00            £10.00
# 1592              2.50             £2.50
# 1593             21.49            £21.49
#
# [25378 rows x 2 columns]

# %%
selected_rows= df['item-price'].astype(str).str.contains('-')
df.loc[selected_rows,'size']=df.loc[selected_rows,'size'].str.split('-').str[0].str.replace('(','')

# %%
df[selected_rows]
# Out:
#           id  offer                                          image-url  \
# 291   724969  False  https://ecom-su-static-prod.wtrecom.com/images...
# 294   676707  False  https://ecom-su-static-prod.wtrecom.com/images...
# 299   646311  False  https://ecom-su-static-prod.wtrecom.com/images...
# 302   574495  False  https://ecom-su-static-prod.wtrecom.com/images...
# 305   544362  False  https://ecom-su-static-prod.wtrecom.com/images...
# 307   513226  False  https://ecom-su-static-prod.wtrecom.com/images...
# 311   444210  False  https://ecom-su-static-prod.wtrecom.com/images...
# 313   415568  False  https://ecom-su-static-prod.wtrecom.com/images...
# 318    79552  False  https://ecom-su-static-prod.wtrecom.com/images...
# 3237  840603  False  https://ecom-su-static-prod.wtrecom.com/images...
# 3279  806334  False  https://ecom-su-static-prod.wtrecom.com/images...
# 3328  724969  False  https://ecom-su-static-prod.wtrecom.com/images...
# 3330  724169  False  https://ecom-su-static-prod.wtrecom.com/images...
# 3360  676707  False  https://ecom-su-static-prod.wtrecom.com/images...
# 3378  646311  False  https://ecom-su-static-prod.wtrecom.com/images...
# 3396  624102  False  https://ecom-su-static-prod.wtrecom.com/images...
# 3435  574495  False  https://ecom-su-static-prod.wtrecom.com/images...
# 3448  544362  False  https://ecom-su-static-prod.wtrecom.com/images...
# 3454  535035  False  https://ecom-su-static-prod.wtrecom.com/images...
# 3471  513226  False  https://ecom-su-static-prod.wtrecom.com/images...
# 3475  509378  False  https://ecom-su-static-prod.wtrecom.com/images...
# 3513  444210  False  https://ecom-su-static-prod.wtrecom.com/images...
# 3536  415568  False  https://ecom-su-static-prod.wtrecom.com/images...
# 3546  397626  False  https://ecom-su-static-prod.wtrecom.com/images...
# 3562   79552  False  https://ecom-su-static-prod.wtrecom.com/images...
# 76    724169  False  https://ecom-su-static-prod.wtrecom.com/images...
# 1193  840603  False  https://ecom-su-static-prod.wtrecom.com/images...
# 1218  806334  False  https://ecom-su-static-prod.wtrecom.com/images...
# 1265  724969  False  https://ecom-su-static-prod.wtrecom.com/images...
# 1296  676707  False  https://ecom-su-static-prod.wtrecom.com/images...
# 1320  646311  False  https://ecom-su-static-prod.wtrecom.com/images...
# 1333  624102  False  https://ecom-su-static-prod.wtrecom.com/images...
# 1359  574495  False  https://ecom-su-static-prod.wtrecom.com/images...
# 1375  544362  False  https://ecom-su-static-prod.wtrecom.com/images...
# 1385  535035  False  https://ecom-su-static-prod.wtrecom.com/images...
# 1393  513226  False  https://ecom-su-static-prod.wtrecom.com/images...
# 1397  509378  False  https://ecom-su-static-prod.wtrecom.com/images...
# 1432  444210  False  https://ecom-su-static-prod.wtrecom.com/images...
# 1461  397626  False  https://ecom-su-static-prod.wtrecom.com/images...
# 1466   79552  False  https://ecom-su-static-prod.wtrecom.com/images...
#
#                                                    page  \
# 291   https://www.waitrose.com/ecom/products/no1-bri...
# 294   https://www.waitrose.com/ecom/products/carvery...
# 299   https://www.waitrose.com/ecom/products/no1-fiv...
# 302   https://www.waitrose.com/ecom/products/no1-30-...
# 305   https://www.waitrose.com/ecom/products/british...
# 307   https://www.waitrose.com/ecom/products/british...
# 311   https://www.waitrose.com/ecom/products/no1-fre...
# 313   https://www.waitrose.com/ecom/products/british...
# 318   https://www.waitrose.com/ecom/products/boneles...
# 3237  https://www.waitrose.com/ecom/products/no1-dry...
# 3279  https://www.waitrose.com/ecom/products/british...
# 3328  https://www.waitrose.com/ecom/products/no1-bri...
# 3330  https://www.waitrose.com/ecom/products/2-beef-...
# 3360  https://www.waitrose.com/ecom/products/carvery...
# 3378  https://www.waitrose.com/ecom/products/no1-fiv...
# 3396  https://www.waitrose.com/ecom/products/medium-...
# 3435  https://www.waitrose.com/ecom/products/no1-30-...
# 3448  https://www.waitrose.com/ecom/products/british...
# 3454  https://www.waitrose.com/ecom/products/no1-fre...
# 3471  https://www.waitrose.com/ecom/products/british...
# 3475  https://www.waitrose.com/ecom/products/fresh-w...
# 3513  https://www.waitrose.com/ecom/products/no1-fre...
# 3536  https://www.waitrose.com/ecom/products/british...
# 3546  https://www.waitrose.com/ecom/products/no1-fre...
# 3562  https://www.waitrose.com/ecom/products/boneles...
# 76    https://www.waitrose.com/ecom/products/2-beef-...
# 1193  https://www.waitrose.com/ecom/products/no1-dry...
# 1218  https://www.waitrose.com/ecom/products/british...
# 1265  https://www.waitrose.com/ecom/products/no1-bri...
# 3454              25.0
# 3471              94.0
# 3475              27.0
# 3513              35.0
# 3536              32.0
# 3546              39.0
# 3562              24.0
# 76                62.0
# 1193              42.0
# 1218              20.0
# 1265              55.0
# 1296              30.0
# 1320              54.0
# 1333              60.0
# 1359             168.0
# 1375              31.0
# 1385              25.0
# 1393              94.0
# 1397              27.0
# 1432              35.0
# 1461              39.0
# 1466              24.0

# %%
df['item-price']=df['item-price-fixed']
df.drop(columns=['item-price-fixed'],inplace=True)

# %%
df[selected_rows][['name','size','item-price']].head()
# Out:
#                                                   name   size  item-price
# 291                          No.1 British Venison Rack    1kg        55.0
# 294  Carvery Leg of British Lamb Studded with Garli...  1.4kg        30.0
# 299     No.1 Five Bone French-Trimmed British Veal Rib    2kg        54.0
# 302   No.1 30 Day Dry Aged Jubilee Rib of British Beef    6kg       168.0
# 305            British Native Breed Whole Beef Brisket  2.2kg        31.0

# %% [markdown]
# ### Exercise 02: What is the distribution of prices per category?

# %%
plot_df=df.groupby('category')['item-price'].describe().reset_index()
plot_df.head()
# Out:
#                category   count       mean        std  min     25%    50%  \
# 0  Baby, Child & Parent   428.0   5.196215   4.677661  0.6  1.8000  3.075
# 1                Bakery   482.0   4.846680   7.750208  0.5  1.6000  2.200
# 2  Beer, Wine & Spirits  1679.0  14.425057  15.720801  0.3  5.3700  9.990
# 3       Best of British   322.0   6.928106  12.570727  0.1  2.7125  4.150
# 4   Dietary & Lifestyle  3337.0   3.795999   4.755322  0.1  1.9500  2.750
#
#        75%     max
# 0   7.2625   25.00
# 1   3.1500   45.00
# 2  17.9900  299.99
# 3   6.0000  168.00
# 4   4.0000  139.99

# %%
plot_df=plot_df.rename(columns={
    '50%':'median',
    '25%':'Q1',
    '75%':'Q3'})
plot_df
# Out:
#                        category   count       mean        std   min      Q1  \
# 0          Baby, Child & Parent   428.0   5.196215   4.677661  0.60  1.8000
# 1                        Bakery   482.0   4.846680   7.750208  0.50  1.6000
# 2          Beer, Wine & Spirits  1679.0  14.425057  15.720801  0.30  5.3700
# 3               Best of British   322.0   6.928106  12.570727  0.10  2.7125
# 4           Dietary & Lifestyle  3337.0   3.795999   4.755322  0.10  1.9500
# 5                Everyday Value   141.0   1.740284   1.202873  0.15  1.1000
# 6                 Food Cupboard  4186.0   2.665160   2.138691  0.35  1.6000
# 7               Fresh & Chilled  3578.0   3.815151   5.267549  0.10  2.0000
# 8                        Frozen   431.0   3.627378   1.544523  0.70  2.6500
# 9                          Home  1075.0   8.595033  10.764164  0.49  3.0000
# 10                    Household   927.0   5.518619   3.934800  0.70  2.9500
# 11                          New   803.0   5.300162   4.948709  0.80  2.5000
# 12                 Organic Shop   671.0   4.937928   5.355143  0.60  2.0000
# 13                          Pet   372.0   5.403306   4.381911  0.65  2.2500
# 14                       Summer  1799.0   6.002223   7.900751  0.30  2.5000
# 15    Tea, Coffee & Soft Drinks  1290.0   3.826000   2.743019  0.40  2.1000
# 16  Toiletries, Health & Beauty  2255.0   7.734093   7.883916  0.55  3.1600
# 17              Waitrose Brands  1591.0   3.005475   3.380658  0.10  1.4000
#
#     median       Q3     max
# 0    3.075   7.2625   25.00
# 1    2.200   3.1500   45.00
# 2    9.990  17.9900  299.99
# 3    4.150   6.0000  168.00
# 4    2.750   4.0000  139.99
# 5    1.350   2.0000    8.00
# 6    2.250   3.0000   43.50
# 7    2.900   4.1425  168.00
# 8    3.500   4.4750   12.00
# 9    5.990  10.5000  159.00
# 10   4.500   7.0000   45.00
# 11   3.500   6.0000   33.00
# 12   2.950   5.0000   35.00
# 13   4.050   7.4500   30.00
# 14   3.750   6.0500  168.00
# 15   3.500   4.7500   59.99
# 16   5.600  10.0000  168.00
# 17   2.100   3.4000   53.20

# %%
# This configures what shows up when you hover your mouse over the plot.
tooltip_setup = (
    layer_tooltips()
        .line('@category')
        .line('[@Q1 , @median , @Q3]')
        .format('@Q1', '£ {.2f}')
        .format('@median', '£ {.2f}')
        .format('@Q3', '£ {.2f}')
)

g = (
    # Maps the columns to the aesthetics of the plot.
    ggplot(plot_df, aes(y='category', x='median', xmin='Q1', xmax='Q3', fill='category')) +

    # GEOMS

    # Add a line range that 'listens to' columns informed in `ymin` and `ymax` aesthetics
    geom_linerange(size=1, alpha=0.75, tooltips=tooltip_setup) +

    # Add points to the plot (listen to `x` and `y` and fill aesthetics)
    geom_point(size=3, stroke=1, shape=21, tooltips=tooltip_setup) +

    # SCALES

    # Remove the legend (we can already read the categories from the y-axis)
    scale_fill_discrete(guide='none') +

    # Specify names for the axes
    scale_y_continuous(name="Categories\n(from largest to smallest median)", expand=[0.05, 0.05]) +
    scale_x_continuous(name="Price (£)", expand=[0., 0.05], format='£ {.2f}', breaks=np.arange(0, 20, 2.5)) +

    # LABELS
    # It's nice when the plot tells you the key takeaways
    labs(title='"Beer, Wine & Spirits" has the highest median price for individual items',
         subtitle="Dots represent the median price, bars represent the 25th and 75th percentiles") +
    theme(axis_text_x=element_text(size=15),
        axis_text_y=element_text(size=17),
        axis_title_x=element_text(size=20),
        axis_title_y=element_text(size=20),
        plot_title=element_text(size=19, face='bold'),
        plot_subtitle=element_text(size=18),
        legend_position='none') +
    ggsize(1000, 500)

)

g
# Out:
#    <div id="QL4v9D"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("QL4v9D");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "category":["Baby, Child & Parent","Bakery","Beer, Wine & Spirits","Best of British","Dietary & Lifestyle","Everyday Value","Food Cupboard","Fresh & Chilled","Frozen","Home","Household","New","Organic Shop","Pet","Summer","Tea, Coffee & Soft Drinks","Toiletries, Health & Beauty","Waitrose Brands"],
# "Q1":[1.8,1.6,5.37,2.7125000000000004,1.95,1.1,1.6,2.0,2.65,3.0,2.95,2.5,2.0,2.25,2.5,2.1,3.16,1.4],
# "median":[3.075,2.2,9.99,4.15,2.75,1.35,2.25,2.9,3.5,5.99,4.5,3.5,2.95,4.05,3.75,3.5,5.6,2.1],
# "Q3":[7.2625,3.15,17.99,6.0,4.0,2.0,3.0,4.1425,4.475,10.5,7.0,6.0,5.0,7.45,6.05,4.75,10.0,3.4]
# },
# "mapping":{
# "x":"median",
# "y":"category",
# "xmin":"Q1",
# "xmax":"Q3",
# "fill":"category"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"category"
# },{
# "type":"float",
# "column":"count"
# },{
# "type":"float",
# "column":"mean"
# },{
# "type":"float",
# "column":"std"
# },{
# "type":"float",
# "column":"min"
# },{
# "type":"float",
# "column":"Q1"
# },{
# "type":"float",
# "column":"median"
# },{
# "type":"float",
# "column":"Q3"
# },{
# "type":"float",
# "column":"max"
# }]
# },
# "ggtitle":{
# "text":"\"Beer, Wine & Spirits\" has the highest median price for individual items",
# "subtitle":"Dots represent the median price, bars represent the 25th and 75th percentiles"
# },
# "theme":{
# "axis_title_x":{
# "size":20.0,
# "blank":false
# },
# "axis_title_y":{
# "size":20.0,
# "blank":false
# },
# "axis_text_x":{
# "size":15.0,
# "blank":false
# },
# "axis_text_y":{
# "size":17.0,
# "blank":false
# },
# "legend_position":"none",
# "plot_title":{
# "face":"bold",
# "size":19.0,
# "blank":false
# },
# "plot_subtitle":{
# "size":18.0,
# "blank":false
# }
# },
# "ggsize":{
# "width":1000.0,
# "height":500.0
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "guide":"none",
# "discrete":true
# },{
# "name":"Categories\n(from largest to smallest median)",
# "aesthetic":"y",
# "expand":[0.05,0.05]
# },{
# "name":"Price (£)",
# "aesthetic":"x",
# "breaks":[0.0,2.5,5.0,7.5,10.0,12.5,15.0,17.5],
# "expand":[0.0,0.05],
# "format":"£ {.2f}"
# }],
# "layers":[{
# "geom":"linerange",
# "mapping":{
# },
# "tooltips":{
# "formats":[{
# "field":"@Q1",
# "format":"£ {.2f}"
# },{
# "field":"@median",
# "format":"£ {.2f}"
# },{
# "field":"@Q3",
# "format":"£ {.2f}"
# }],
# "lines":["@category","[@Q1 , @median , @Q3]"]
# },
# "data_meta":{
# },
# "size":1.0,
# "alpha":0.75,
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "tooltips":{
# "formats":[{
# "field":"@Q1",
# "format":"£ {.2f}"
# },{
# "field":"@median",
# "format":"£ {.2f}"
# },{
# "field":"@Q3",
# "format":"£ {.2f}"
# }],
# "lines":["@category","[@Q1 , @median , @Q3]"]
# },
# "data_meta":{
# },
# "size":3.0,
# "stroke":1.0,
# "shape":21.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"1"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ### Exercise 03: Are there any products that appear in multiple categories?

# %%
duplicates_df=df.groupby('name')['category'].unique().reset_index()
duplicates_df
# Out:
#                                                 name  \
# 0        019521 - Essential Flageolet Beans in Water
# 1             035738 - Solero Exotic Ice cream Lolly
# 2              044889 - Essential Double Cream Large
# 3                     060167 - Kronenbourg 1664 Cans
# 4                 086143 - Cooks' Ingredients Garlic
# ...                                              ...
# 15413        £100,000 a Month for a Year Scratchcard
# 15414        Öpso Japanese Sakura Tree Reed Diffuser
# 15415  Öpso Mediterranean Citrus Grove Reed Diffuser
# 15416         Öpso Nordic Birch Forest Reed Diffuser
# 15417             Ürziger Würzgarten Kabinett Loosen
#
#                                                 category
# 0      [Dietary & Lifestyle, Food Cupboard, Waitrose ...
# 1                  [Dietary & Lifestyle, Frozen, Summer]
# 2                     [Fresh & Chilled, Waitrose Brands]
# 3                                 [Beer, Wine & Spirits]
# 4      [Dietary & Lifestyle, Fresh & Chilled, Waitros...
# ...                                                  ...
# 15413                                             [Home]
# 15414                                  [Home, Household]
# 15415                                  [Home, Household]
# 15416                                  [Home, Household]
# 15417            [Beer, Wine & Spirits, Fresh & Chilled]
#
# [15418 rows x 2 columns]

# %%
duplicates_df['counts']=df.groupby('name')['category'].nunique().values
duplicates_df.sort_values('counts',ascending=False)
# Out:
#                                                  name  \
# 3512                            Duchy Organic Houmous
# 4678                              Essential Sweetcorn
# 3608   Duchy Organic Unhomogenised Whole Milk 4 Pints
# 4404                                  Essential Limes
# 4234                               Essential Cucumber
# ...                                               ...
# 15388                  itsu Rice Cakes Milk Chocolate
# 15390                    itsu Salted Caramel Bao Buns
# 15391                         itsu Satay Rice Noodles
# 15376                  itsu Dark Chocolate Rice Cakes
# 15377              itsu Frozen Hoisin Duck 6 Bao'Buns
#
#                                                 category  counts
# 3512   [Dietary & Lifestyle, Fresh & Chilled, New, Or...       6
# 4678   [Dietary & Lifestyle, Everyday Value, Food Cup...       6
# 3608   [Best of British, Dietary & Lifestyle, Fresh &...       6
# 4404   [Beer, Wine & Spirits, Dietary & Lifestyle, Ev...       6
# 4234   [Beer, Wine & Spirits, Dietary & Lifestyle, Ev...       6
# ...                                                  ...     ...
# 15388                                    [Food Cupboard]       1
# 15390                              [Dietary & Lifestyle]       1
# 15391                                    [Food Cupboard]       1
# 15376                                    [Food Cupboard]       1
# 15377                                           [Frozen]       1
#
# [15418 rows x 3 columns]

# %%
duplicates_df=duplicates_df[duplicates_df['counts']>1]
duplicates_df.sort_values('counts')
# Out:
#                                                  name  \
# 64                      33cm Floral Oasis Napkins 20s
# 12309                  Tri-Molecular Hyaluronic Serum
# 2               044889 - Essential Double Cream Large
# 12313                         Trimmed Mange Tout Peas
# 5              10 Mins to Bed Where's Little Dinosaur
# ...                                               ...
# 3512                            Duchy Organic Houmous
# 3608   Duchy Organic Unhomogenised Whole Milk 4 Pints
# 4404                                  Essential Limes
# 4678                              Essential Sweetcorn
# 4234                               Essential Cucumber
#
#                                                 category  counts
# 64                                        [Home, Summer]       2
# 12309  [Dietary & Lifestyle, Toiletries, Health & Bea...       2
# 2                     [Fresh & Chilled, Waitrose Brands]       2
# 12313             [Dietary & Lifestyle, Fresh & Chilled]       2
# 5                                            [Home, New]       2
# ...                                                  ...     ...
# 3512   [Dietary & Lifestyle, Fresh & Chilled, New, Or...       6
# 3608   [Best of British, Dietary & Lifestyle, Fresh &...       6
# 4404   [Beer, Wine & Spirits, Dietary & Lifestyle, Ev...       6
# 4678   [Dietary & Lifestyle, Everyday Value, Food Cup...       6
# 4234   [Beer, Wine & Spirits, Dietary & Lifestyle, Ev...       6
#
# [6657 rows x 3 columns]

# %%
df[df.duplicated('id',keep='first')].count()
# Out:
# id                   9323
# offer                9323
# image-url            9323
# page                 9323
# name                 9317
# size                 9299
# item-price           9317
# price-per-unit       9227
# offer-description    2522
# category             9323
# dtype: int64
